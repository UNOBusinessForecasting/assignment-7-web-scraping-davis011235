# %% [markdown]
# ## Collecting data from websites
#
# Have you ever needed to collect data from websites where the data is not made readily available? If you have, then you probably spent a significant amount of time copying and pasting from the website to a spreadsheet, and trying to carefully collect only the information that you need, while avoiding mistakes based on copying and pasting or typing. If your project required that data be collected from *many* pages, then this likely became a painful and repetitive effort that occupied a substantial amount of time.
#
# Fortunately, your knowledge of Python can facilitate the data collection process through libraries designed to automate the collection of data from large numbers of pages. This class, we will focus on how to use a few of these libraries to streamline the collection of information from websites. The best way to understand this process is to do it, so we will be walking through the process while learning about why we scrape data the way that we do.

# %% [markdown]
# ## Parsing websites with Python
#
# Obviously, if we want to scrape a website, we will first want to *access* that website. We can do this with the `requests` library, like we did before to grab some text for our regex experiments.

# %%
import requests
myPage = requests.get("https://brickset.com/sets/year-2020")

# %% [markdown]
# During this lesson, we will be using [brickset.com](https://brickset.com/) as our example. This is a GREAT website for learning to scrape, because the website is so simple that we can quickly determine whether or not the results of our scrape match the true output of the website. Even better, the website is about Legos, and Legos are the best!
#
# Now we will focus on exploring the page to see what information we can extract.
#
# ### Process the HTML

# %%
from bs4 import BeautifulSoup

parsed = BeautifulSoup(myPage.text)

# %% [markdown]
# The code above imports the `BeautifulSoup` library/function, and prepares our requested URL for scraping. When we feed our website into the parser, we need to make sure to pass the `text` attribute of the requested URL, since this is the place in which the full HTML of the page is stored. If we just pass the `myPage` object, then we will be unable to parse the HTML like we want to. Now, we simply store a parsed website as an object (in this case we call it `parsed`), and we are ready to go.

# %%
parsed.title

# %% [markdown]
#     <title>2020  | Brickset: LEGO set guide and database</title>
#
#
#
# `BeautifulSoup`'s parsed pages are structured based on the HTML tags that are encountered within the page. For example, above we requested the `title` tag from the page, and we got back the full tag, as well as all content within that tag. In order to only return the text inside the tag, we can use the following code:

# %%
parsed.title.text

# %% [markdown]
#     '2020  | Brickset: LEGO set guide and database'
#
#
#
# For a tag with nothing else embedded inside, this is a great way to extract the text. However, many tags will contain one or more other tags, which add to the formatting of the page. The tag that we will be most interested in for now is the `article` tag, which is wrapped around each individual Lego set that is listed on the website. If we just look for the article tag like we did with the title, then we will only see the first article on the page:

# %%
parsed.article

# %% [markdown]
#     <article class="set">
#     <a class="highslide plain mainimg" href="/assets/images/misc/blankbox.gif" onclick="return hs.expand(this)"><img onerror="this.src='/assets/images/spacer2.png'" src="/assets/images/misc/blankbox.gif" title="356-2: Basic Building Set with Storage Case"/></a>
#     <div class="highslide-caption">
#     <h1>Basic Building Set with Storage Case</h1><div class="tags floatleft"><a href="/sets/356-2/Basic-Building-Set-with-Storage-Case">356-2</a> <a href="/sets/theme-Basic">Basic</a> <a class="year" href="/sets/theme-Basic/year-2020">2020</a> </div><div class="floatright">©2020 LEGO Group</div>
#     <div class="pn">
#     <a href="#" onclick="return hs.previous(this)" title="Previous (left arrow key)">« Previous</a>
#     <a href="#" onclick="return hs.next(this)" title="Next (right arrow key)">Next »</a>
#     </div>
#     </div>
#     <div class="meta"><h1><a href="/sets/356-2/Basic-Building-Set-with-Storage-Case"><span>356: </span> Basic Building Set with Storage Case</a></h1><div class="tags"><a href="/sets/356-2/Basic-Building-Set-with-Storage-Case">356-2</a> <a href="/sets/theme-Basic">Basic</a> <a class="year" href="/sets/theme-Basic/year-2020">2020</a> </div><div class="tags"><span id="tags30652"></span></div><div class="col"><dl><dt>Pieces</dt><dd>1987</dd><dt>Set type</dt><dd>Normal</dd></dl></div><div class="col"><dl></dl><dl class="highlight"></dl></div></div><div class="action"><dl class="admin"><dt class="hideingallery">Our community</dt><dd class="hideingallery"><a class="popuplink" href="ownedBy?SetID=30652">0 own this set</a>, 3 want it</dd></dl><dl class="admin"><dt class="hideingallery">Your collection</dt><dd><a href="/signup">Sign up</a> for a free account to record your LEGO collection here at Brickset</dd></dl><dl class="buylinks"><dt>Buy this set at</dt><dd><ul><li>
#     </li><li>
#     <a class="amazon" href="https://www.amazon.com/s/?url=search-alias=aps&amp;field-keywords=LEGO%20356&amp;tag=brickset-20&amp;link_code=wql&amp;camp=212361&amp;creative=380601&amp;_encoding=UTF-8">Amazon</a>
#     </li><li>
#     <a class="ebay" href="https://rover.ebay.com/rover/1/711-53200-19255-0/1?icep_ff3=9&amp;pub=5574779132&amp;toolid=10001&amp;campid=5336183597&amp;customid=&amp;icep_uq=LEGO+356&amp;icep_sellerId=&amp;icep_ex_kw=&amp;icep_sortBy=12&amp;icep_catId=&amp;icep_minPrice=&amp;icep_maxPrice=&amp;ipn=psmain&amp;icep_vectorid=229466&amp;kwid=902099&amp;mtid=824&amp;kw=lg">eBay</a>
#     </li><li>
#     <a class="bricklink" href='http://alpha.bricklink.com/pages/clone/catalogitem.page?S=356-2#T=S&amp;O={"ss":"US"}'>BrickLink</a>
#     </li></ul></dd></dl></div></article>
#
#
#
# Wow! There sure is a lot of stuff for us to work through within that tag! It turns out that the article tag contains *everything* related to a particular set, so we will have to work through that information more carefully if we would like to be able to scrape information about each set.
#
# The first thing that we need to do, though, is collect ALL of the article tags (or all of the sets), so that we can scrape each one and collect the most useful information.

# %% [markdown]
# ## Navigating scraped data
#
# Our processed website has some other tools besides being able to reference each tag. One of the most helpful is a method called `find_all`, which will allow us to look in a specific portion of the page (or across the whole page) for *all instances* of a specific tag. Before, we could only see the first instance of the article tag, but this will allow us to find all the articles on a page!
#
# In order to not end up with a massive text blob for output, let's store the results of our `find_all` method in a list.

# %%
a = [i for i in parsed.find_all('article')]

# %% [markdown]
# To store the article tags in a list, we use a simple list comprehension, so that each separate article tag is a new entry in the list called `a`. One of the really cool things about `BeautifulSoup` is that each object is treated just like the full parsed webpage: we can use tags as attributes to walk through each of our new objects in the list.
#
# Let's try finding a `ul` tag inside of the first article:

# %%
a[1].ul

# %% [markdown]
#     <ul><li>
#     <a class="lego" href="https://click.linksynergy.com/link?id=oSv/vWYkQIY&amp;offerid=115554.10270&amp;type=15&amp;murl=https%3A%2F%2Fwww.lego.com%2Fen-us%2Fproduct%2Fbookshop-10270">LEGO</a></li><li>
#     <a class="amazon" href="https://www.amazon.com/s/?url=search-alias=aps&amp;field-keywords=LEGO%2010270&amp;tag=brickset-20&amp;link_code=wql&amp;camp=212361&amp;creative=380601&amp;_encoding=UTF-8">Amazon</a>
#     </li><li>
#     <a class="ebay" href="https://rover.ebay.com/rover/1/711-53200-19255-0/1?icep_ff3=9&amp;pub=5574779132&amp;toolid=10001&amp;campid=5336183597&amp;customid=&amp;icep_uq=LEGO+10270&amp;icep_sellerId=&amp;icep_ex_kw=&amp;icep_sortBy=12&amp;icep_catId=&amp;icep_minPrice=&amp;icep_maxPrice=&amp;ipn=psmain&amp;icep_vectorid=229466&amp;kwid=902099&amp;mtid=824&amp;kw=lg">eBay</a>
#     </li><li>
#     <a class="bricklink" href='http://alpha.bricklink.com/pages/clone/catalogitem.page?S=10270-1#T=S&amp;O={"ss":"US"}'>BrickLink</a>
#     </li></ul>
#
#
#
# Awesome! We can walk through that list if we would like, as well!
#
# Next, let's see how many articles are stored on each page of search results:

# %%
parsed.find("ul", class_="pagelength").span.text

# %% [markdown]
#     '25'
#
#
#
# It looks like each results page has 25 or fewer results. How did we know to look for a `ul` tag that had the class `pagelength`? We opened a page of results up, and we used the developer "Inspect" tool built into our browser to help us find the part of the page that tells us how many results will be shown on each page. As we prepare to scrape a page, we will spend a lot of time going back and forth between the website as we see it, and the code that we are designing to scrape that website.
#
# As we look through our list of articles, though, we will want to start extracting information that will help us learn about each Lego set. Let's try our hand at finding the name of the sets, and the price of the sets in Euros. Fortunately, the title of each set will be very easy to find. If we inspect the title of the first result (using the link that we started with at the top of the notebook), we can see that the name of the set is stored within the article tag using an `h1` tag. Let's request that from our list:

# %%
a[1].h1.text

# %% [markdown]
#     'Basic Building Set with Storage Case'
#
#
#
# Perfect! We get back the text title for our first search result! We can also return the title of each set on the page:

# %%
[i.h1.text for i in a]

# %% [markdown]
#     ['Basic Building Set with Storage Case',
#      'Bookshop',
#      'Fiat 500',
#      'Old Trafford - Manchester United',
#      'Haunted House',
#      '{?}',
#      '{?}',
#      '{?}',
#      'Crocodile Locomotive',
#      'Heart Box',
#      'Brick Box',
#      'Deluxe Brick Box',
#      'Alphabet Truck',
#      'Fire Truck',
#      'Tow Truck',
#      'Batcave',
#      "Elsa and Olaf's Tea Party",
#      'Super Heroes Lab',
#      "Ariel's Undersea Castle",
#      "Lightning McQueen's Race Day",
#      'Playroom',
#      'Bedroom',
#      'Pizza Stand',
#      'Bakery',
#      'Modular Playhouse']
#
#
#
# That was the easy part. Now that we have the set names, we need to find their prices. We will start by finding their prices on the website itself. We can see that the prices are listed in both dollars and Euros, and that they are always shown next to text that says "RRP". This stands for Recommended Retail Price, and is the number we want to collect.
#
# Our first step in extracting the price is to note that, because the price changes from set to set, we are going to have to find some other consistent marker from which we can reference the price. That marker is the text "RRP". We need to describe a way to always reach that text, no matter which set we are focused on. If we inspect the page, we will see that "RRP" is contained in a `dt` tag. There are several of these tags, each containing different information about the set, so we will need to make sure that we get the right one.
#
# Using the `.find` method, we can tell `BeautifulSoup` to look for a tag of specific kind (in this case, `dt`) with some attribute (in this case, text that is equal to "RRP").

# %%
a[1].find('dt', text="RRP")

# %% [markdown]
#     <dt>RRP</dt>
#
#
#
# Got it! This isn't so bad if we just move slowly. Next up, we need to make our way from the "RRP" tag to the tag containing the price. It turns out that `dt` tags are part of a table, and each one will correspond to a `dd` tag. These tags within a table are considered **siblings**, meaning that they exist embedded within the same tag as one another.
#
# Since the `dd` tag containing the price ALWAYS immediately follows the `dt` containing "RRP", we can use the `.find_next_sibling()` method to move from the `dt` tag to the `dd` tag! The price is contained as the text of the `dd` tag, so let's go ahead and grab that text, now.

# %%
a[1].find('dt', text="RRP").find_next_sibling().text

# %% [markdown]
#     '$179.99, 155.96€ | More'
#
#
#
# Almost there.... Unfortunately, the text contains more stuff than just the price in Euros. It turns out that the website just has a blob of text that contains prices, possibly in dollars, possibly in Euros, and possibly both, with some extra text at the end. Since price isn't a consistent number of digits, we need a way to recognize patterns in text and extract only the part that we want.
#
# Regular expression comes to the rescue!

# %%
import re

re.search(r'(\d+.\d+)(\u20AC)', a[1].find('dt', text="RRP").find_next_sibling().text, re.UNICODE).groups()[0]

# %% [markdown]
#     '155.96'
#
#
#
# `r'(\d+.\d+)(\u20AC)'` is a regular expression that looks for one or more numbers before a period, a period, and one or more numbers after the period followed by the Euro symbol (`\u20AC` is the code that represents the Euro symbol). We simply provide the string to the `re.search` function, along with our regular expression and an extra argument (`re.UNICODE`) that allows us to find less common characters like the Euro symbol.
#
# When we get back the results from this search, we only need the first group (or value in parentheses), which omits the Euro symbol. This will return only the number value representing the price of the set. It's a string, but we can easily convert it to a number using the `float()` function.
#
# Now that we know how to find each of the two values that we care about, it is time to start formalizing our code with a `for` loop to grab the same pieces of information from each set. We can use our loop to walk through each `article` tag and extract the relevant information.

# %%
data = []

for i in a:
    row = []
    row.append(i.h1.text)
    try:
        row.append(re.search(r'(\d+.\d+)(\u20AC)', i.find('dt', text="RRP").find_next_sibling().text, re.UNICODE).groups()[0])
    except:
        row.append('')
    data.append(row)

# %% [markdown]
# We created an empty list called `data`, and our `for` loop was used to add rows to that list. Each row consists of a list of two items: set name and set price. Once we have created the list representing that row, we simply append it to the `data` list and move on to the next set.
#
# The next step (below) is to create a Data Frame based on our list called `data`, and to name our columns. This provides easy structure and functionality to our data:

# %%
import pandas as pd

data = pd.DataFrame(data, columns = ['Set', 'Price_Euro'])

data

# %% [markdown]
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Set</th>
#       <th>Price_Euro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Basic Building Set with Storage Case</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bookshop</td>
#       <td>155.96</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Fiat 500</td>
#       <td>77.97</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Old Trafford - Manchester United</td>
#       <td>263.18</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Haunted House</td>
#       <td>224.19</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{?}</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{?}</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{?}</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Crocodile Locomotive</td>
#       <td>97.47</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Heart Box</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Brick Box</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Deluxe Brick Box</td>
#       <td>48.73</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Alphabet Truck</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Fire Truck</td>
#       <td>4.86</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Tow Truck</td>
#       <td>4.86</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Batcave</td>
#       <td>34.11</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Elsa and Olaf's Tea Party</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Super Heroes Lab</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Ariel's Undersea Castle</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Lightning McQueen's Race Day</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Playroom</td>
#       <td>14.61</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Bedroom</td>
#       <td>14.61</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Pizza Stand</td>
#       <td>9.74</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Bakery</td>
#       <td>38.98</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Modular Playhouse</td>
#       <td>58.48</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Scraping many pages
#
# Now that we have established a pattern of code that is able to collect the information we desire, it is time to make sure that we can collect the same information from each page of search results. It is typically insufficient to collect only one page of search results, so we want to be able to follow the links in our search from page to page in order to continue collecting data.
#
# On the page, we can inspect the button that navigates from one page to the next. We find that the element is an `li` or list item tag, with a class of `next`. Using the `find` method, we can can then extract the `href` parameter from the `a` tag representing the link that takes us to the next page:

# %%
nextPage = parsed.find('li', class_="next").a['href']

nextPage

# %% [markdown]
#     'https://brickset.com/sets/year-2020/page-2'
#
#
#
# This link certainly looks like it will take us to the next page of results! Now, we can consolidate the code that we used above into a single code block, so that we can recycle our code to collect data from another page of search results. Below is the code that we have collected so far, applied to the second page of results.

# %%
myPage = requests.get(nextPage)

parsed = BeautifulSoup(myPage.text)
a = [i for i in parsed.find_all('article')]

newData = []

for i in a:
    row = []
    row.append(i.h1.text)
    try:
        row.append(re.search(r'(\d+.\d+)(\u20AC)', i.find('dt', text="RRP").find_next_sibling().text, re.UNICODE).groups()[0])
    except:
        row.append('')
    newData.append(row)

newData = pd.DataFrame(newData, columns = ['Set', 'Price_Euro'])

newData

# %% [markdown]
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Set</th>
#       <th>Price_Euro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Bulldozer</td>
#       <td>9.74</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Truck &amp; Tracked Excavator</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Wrecking Ball Demolition</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Tower Crane &amp; Construction</td>
#       <td>116.97</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Creative Animals</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Creative Blue Bricks</td>
#       <td>4.86</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Creative Green Bricks</td>
#       <td>4.86</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Bricks and Houses</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Bricks and Lights</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>White Baseplate</td>
#       <td>7.79</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Bricks and Animals</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Bricks Bricks Plates</td>
#       <td>68.23</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Robot</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Tokyo</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Dubai</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>The White House</td>
#       <td>97.47</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>BigFig Creeper and Ocelot</td>
#       <td>14.61</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>BigFig Pig with Baby Zombie</td>
#       <td>14.61</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>The Panda Nursery</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>The Pillager Outpost</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>The Illager Raid</td>
#       <td>68.23</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>The Crafting Box 3.0</td>
#       <td>77.97</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>The Taiga Adventure</td>
#       <td>9.74</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>The Redstone Battle</td>
#       <td>53.60</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>International Space Station</td>
#       <td>68.23</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# Additionally, we can concatenate our Data Frames so that we have a single Data Frame containing all of the results from our scrape. After we concatenate our data, it is good practice to reset the index using the `.reset_index()` method. This will overwrite the index of the Data Frame so that it does not have any repeat values. Be sure to include the argument `drop=True`, so that the old index isn't added back into your Data Frame.

# %%
data = pd.concat([data, newData], axis=0).reset_index(drop=True)

data

# %% [markdown]
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Set</th>
#       <th>Price_Euro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Basic Building Set with Storage Case</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bookshop</td>
#       <td>155.96</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Fiat 500</td>
#       <td>77.97</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Old Trafford - Manchester United</td>
#       <td>263.18</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Haunted House</td>
#       <td>224.19</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>{?}</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>{?}</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>{?}</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Crocodile Locomotive</td>
#       <td>97.47</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Heart Box</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Brick Box</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Deluxe Brick Box</td>
#       <td>48.73</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Alphabet Truck</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>Fire Truck</td>
#       <td>4.86</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Tow Truck</td>
#       <td>4.86</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>Batcave</td>
#       <td>34.11</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Elsa and Olaf's Tea Party</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Super Heroes Lab</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>Ariel's Undersea Castle</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>Lightning McQueen's Race Day</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Playroom</td>
#       <td>14.61</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Bedroom</td>
#       <td>14.61</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Pizza Stand</td>
#       <td>9.74</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>Bakery</td>
#       <td>38.98</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>Modular Playhouse</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>Bulldozer</td>
#       <td>9.74</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>Truck &amp; Tracked Excavator</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>Wrecking Ball Demolition</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>28</th>
#       <td>Tower Crane &amp; Construction</td>
#       <td>116.97</td>
#     </tr>
#     <tr>
#       <th>29</th>
#       <td>Creative Animals</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>30</th>
#       <td>Creative Blue Bricks</td>
#       <td>4.86</td>
#     </tr>
#     <tr>
#       <th>31</th>
#       <td>Creative Green Bricks</td>
#       <td>4.86</td>
#     </tr>
#     <tr>
#       <th>32</th>
#       <td>Bricks and Houses</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>33</th>
#       <td>Bricks and Lights</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>34</th>
#       <td>White Baseplate</td>
#       <td>7.79</td>
#     </tr>
#     <tr>
#       <th>35</th>
#       <td>Bricks and Animals</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>36</th>
#       <td>Bricks Bricks Plates</td>
#       <td>68.23</td>
#     </tr>
#     <tr>
#       <th>37</th>
#       <td>Robot</td>
#       <td></td>
#     </tr>
#     <tr>
#       <th>38</th>
#       <td>Tokyo</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>39</th>
#       <td>Dubai</td>
#       <td>58.48</td>
#     </tr>
#     <tr>
#       <th>40</th>
#       <td>The White House</td>
#       <td>97.47</td>
#     </tr>
#     <tr>
#       <th>41</th>
#       <td>BigFig Creeper and Ocelot</td>
#       <td>14.61</td>
#     </tr>
#     <tr>
#       <th>42</th>
#       <td>BigFig Pig with Baby Zombie</td>
#       <td>14.61</td>
#     </tr>
#     <tr>
#       <th>43</th>
#       <td>The Panda Nursery</td>
#       <td>19.49</td>
#     </tr>
#     <tr>
#       <th>44</th>
#       <td>The Pillager Outpost</td>
#       <td>29.23</td>
#     </tr>
#     <tr>
#       <th>45</th>
#       <td>The Illager Raid</td>
#       <td>68.23</td>
#     </tr>
#     <tr>
#       <th>46</th>
#       <td>The Crafting Box 3.0</td>
#       <td>77.97</td>
#     </tr>
#     <tr>
#       <th>47</th>
#       <td>The Taiga Adventure</td>
#       <td>9.74</td>
#     </tr>
#     <tr>
#       <th>48</th>
#       <td>The Redstone Battle</td>
#       <td>53.60</td>
#     </tr>
#     <tr>
#       <th>49</th>
#       <td>International Space Station</td>
#       <td>68.23</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## Moving from script to function
#
# We talked about functions earlier in the term as an excellent way to make our code more reusable, and to eliminate the need to copy and paste code with the risk of creating more typos and places for code to be updated. Now that we know how to scrape useful information from a website, let's create a function to do the work for us, so that we don't have to copy and paste the code for each subsequent page of search results.
#
# In order to make our code into a function, we will have to create a function that takes a starting URL (the URL for our search results), and returns a Data Frame after reading through each page of the search results. We will have to perform some abstraction to make our code work on each page, but the differences are pretty minor:
#
# - Use `requests.get()` on the URL passed to the function
# - Check whether or not a "next" page exists
#     - If there IS a next page, we need to call the function on *that* page, then merge the results
#     - If there is NOT a next page, we return the existing data as a Data Frame.
#
# Take some time to examine the code below and how each of these changes is made:

# %%
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
import time

# A function to collect lego sets from search results on brickset.com
def collectLegoSets(startURL):
    # Add headers to imitate a real browser
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/'
    }
    # Retrieve starting URL
    myPage = requests.get(startURL)

    # Parse the website with Beautiful Soup
    parsed = BeautifulSoup(myPage.text)

    # Grab all sets from the page
    a = [i for i in parsed.find_all('article')]

    # Create and empty data set
    newData = []

    # Iterate over all sets on the page
    for i in a:
        row = []
        # Add the set name to the row of data
        row.append(i.h1.text)
        try:
            # Extract price and translate to a floating point number from string, append to row IF PRICE EXISTS
            row.append(float(re.search(r'(\d+.\d+)(\u20AC)', i.find('dt', text="RRP").find_next_sibling().text, re.UNICODE).groups()[0]))
        except:
            # Missing value for sets with no price, append to row IF NO PRICE EXISTS
            row.append(np.nan)

        # Add the row of data to the dataset
        newData.append(row)

    newData = pd.DataFrame(newData, columns = ['Set', 'Price_Euro'])

    # Check if there are more results on the "next" page
    try:
        nextPage = parsed.find('li', class_="next").a['href']
    except:
        nextPage = None

    # If there is another page of results, grab it and combine
    if nextPage:
        # Tell our program not to load new pages too fast by "sleeping" for two seconds before
        #   going to the next page
        time.sleep(2)
        # Merge current data with next page
        return pd.concat([newData, collectLegoSets(nextPage)], axis=0)
    # Otherwise return the current data
    else:
        return newData

# %% [markdown]
# *Note: We sometimes need to use **headers** (text telling the website what kind of browser we are "using") so that we are able to access the website we want to scrape. Mileage will vary by website*
# (Shoutout to Kiran Best of Aalto University for finding the right header to keep this site working as an example)
#
# Observe that we use several `try`-`except` blocks. These code blocks permit us to write code that *might* result in an error. This is the code that is indented beneath the `try` keyword. Then, we write code that should be executed whenever an error *does* occur under the `except` keyword. In this way, we prevent errors from breaking our function, and we can better control the data that is recorded in our Data Frame. Let's run the code now:

# %% [markdown]
# lego2020 = collectLegoSets("https://brickset.com/sets/year-2020")
#
# lego2020

# %% [markdown]
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Set</th>
#       <th>Price_Euro</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Basic Building Set with Storage Case</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Bookshop</td>
#       <td>155.96</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Fiat 500</td>
#       <td>77.97</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Old Trafford - Manchester United</td>
#       <td>263.18</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Haunted House</td>
#       <td>224.19</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Building LEGO Trains</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Porsche 911: Legends Made of LEGO</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>Iconic Objects Made From LEGO Bricks</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>Newsstand</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Valentine's Bear</td>
#       <td>NaN</td>
#     </tr>
#   </tbody>
# </table>
# <p>663 rows × 2 columns</p>
# </div>
#
#
#
# There you have it! A single, easy-to-read function that will collect data on all Lego sets from the year 2020 into a Data Frame for us to analyze. We can even use this Data Frame to streamline calculations:

# %%
lego2020['Price_Euro'].mean()

# %% [markdown]
#     40.550406504065045
#
#
#
# Based on the data we have collected, the mean price (in Euros) of 2020 Lego sets is 40.61€.
#
# Now, it's your turn to collect data!
#
# **Solve it!**
#
# Update the code used in this lesson to extract the following information regarding Lego sets from the year 2019:
# - Name of the set
# - Price of the set (in Euros)
# - Number of pieces
# - Number of minifigs
#
# You should collect this information for ALL lego sets from 2019 (there are 849 as of Jan 2024). Store your results in a csv called `lego2019.csv` using code that you save in the cell labeled `#si-exercise`. The columns should be labeled `Set`, `Price_Euro`, `Pieces`, `Minifigs`, respectively. The Data Frame should have the first page of results at the top, and the last page of results at the bottom (this order will enable comparison of your results with mine). You will receive points for the following:
#
# - `lego2019.csv` contains 849 entries [1 point]
# - Columns are labeled `Set`, `Price_Euro`, `Pieces`, `Minifigs`, respectively [1 point]
# - Column `Set` contains the correct names for each set [1 point]
# - Column `Price_Euro` contains the correct price in Euros for each set (missing prices should be replaced with `np.nan`) [1 point]
# - Column `Pieces` contains the correct number of pieces (replaced with `np.nan` where missing) [1 point]
# - A function called `collectLegoSets` is defined in your code [1 point]
# - Your code writes the results of a DataFrame to CSV (be sure NOT to save the index column!) [1 point]
#
#
# *WARNING: This submission may be slow to grade, since it will take a while for your code to scrape the website and process the data! Be patient.*
#
# Please put ALL NECESSARY CODE into the cell!

# %%
#si-exercise
import requests
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import re
import time
import random

# A function to collect lego sets from search results on brickset.com
def collectLegoSets(startURL):
    # Putting header back. Not the problem
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.0.0 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
        'Referer': 'https://www.google.com/'}

    # Retrieve starting URL
    myPage = requests.get(startURL)

    # Parse the website with Beautiful Soup
    parsed = BeautifulSoup(myPage.text)

    # Grab all sets from the page
    a = [i for i in parsed.find_all('article')]

    # Create and empty data set
    newData = []

    # Iterate over all sets on the page
    for i in a:
        row = []

        # Add the set name to the row of data. Can title be missing? Added except in case
        try:
            row.append(i.h1.text)
        except:
            row.append('')

        try:
            # Extract price and translate to a floating point number from string, append to row IF PRICE EXISTS
            row.append(float(re.search(r'(\u20AC)(\d+[.]\d{2})', i.find('dt', string = 'RRP').find_next_sibling().text).groups()[1])) #[0] or [1]???
        except:
            # Missing value for sets with no price, append to row IF NO PRICE EXISTS
            row.append(np.nan)

        # Get pieces, if there
        try:
            row.append(float(i.find('dt', string = 'Pieces').find_next_sibling().text)) #float?
        except:
            row.append(np.nan)

        # Get minifigs, if there (Just want #, not full phrase, right?) float?
        # Why am I getting minifigs all Nan now? What's raising the exception? forgot .text
        try:
            row.append(float(re.search(r'(\d+)',i.find('dt', string='Minifigs').find_next_sibling('dd').find('a', class_='plain').text).group(0)))
        except:
            row.append(np.nan)

        # Add the row of data to the dataset
        newData.append(row)
        print(row)

    newData = pd.DataFrame(newData, columns = ['Set', 'Price_Euro', 'Pieces', 'Minifigs'])

    # Check if there are more results on the "next" page
    try:
        nextPage = parsed.find('li', class_="next").a['href']
    except:
        nextPage = None

    # If there is another page of results, grab it and combine
    if nextPage:
        # Tell our program not to load new pages too fast by "sleeping" for two seconds before (changed to 5 + X)
        #   going to the next page
        time.sleep(5+ random.uniform(0,10))
        # Merge current data with next page
        return pd.concat([newData, collectLegoSets(nextPage)], axis=0)
    # Otherwise return the current data
    else:
        return newData

#Now, how tf do I get the csv

# Are we trying to get the function to return csv, or just return csv in code chunk? Glancing at grading code, think fn should return df.
# pandas has to_csv Use index = False, could add to fn

collectLegoSets('https://brickset.com/sets/year-2019').to_csv('lego2019.csv', index=False)

# Y'know, I used to like lego

# Whhyyyyyy??????????

# Never before have I been so happy to see the phrase "Mini X-wing Fighter"
# Out:
# ['Corner Garage', 179.99, 2569.0, 6.0]
# ['Ford Mustang', 169.99, 1471.0, nan]
# ['NASA Apollo 11 Lunar Lander', 99.99, 1087.0, 2.0]
# ['Gingerbread House', 89.99, 1477.0, 2.0]
# ['Harley-Davidson Fat Boy', 89.99, 1023.0, nan]
# ['Woody & RC', 9.74, 69.0, 1.0]
# ["Duke Caboom's Stunt Show", 19.49, 120.0, 2.0]
# ["Buzz and Bo Peep's Playground Adventure", 24.36, 139.0, 3.0]
# ['RV Vacation', 34.11, 178.0, 3.0]
# ["Buzz & Woody's Carnival Mania!", 49.99, 230.0, 5.0]
# ['Carnival Thrill Coaster', 19.49, 98.0, 2.0]
# ['My First Tow Truck', 9.74, 11.0, nan]
# ['My First Balancing Animals', 14.61, 15.0, nan]
# ['My First Fun Puzzle', 19.49, 15.0, nan]
# ['My First Car Creations', 19.99, 34.0, nan]
# ['Creative Fun', 34.99, 120.0, 1.0]
# ["Mickey's Vacation House", 48.73, 57.0, 3.0]
# ['Spider-Man vs. Electro', 19.99, 29.0, 2.0]
# ['Toy Story Train', 19.99, 21.0, 2.0]
# ["Emmet and Lucy's Visitors from the DUPLO Planet", 29.99, 53.0, 2.0]
# ['My First Minnie Build', 9.99, 10.0, nan]
# ['My First Mickey Build', 9.74, 9.0, nan]
# ['Frozen Ice Castle', 49.99, 59.0, 3.0]
# ['Police Bike', 9.99, 8.0, 1.0]
# ['Fire Truck', 19.99, 21.0, 2.0]
# ['Police Station', 29.99, 38.0, 3.0]
# ['Fire Station', 49.99, 76.0, 2.0]
# ['Baby Animals', 9.74, 9.0, nan]
# ['Tropical Island', 59.99, 73.0, 3.0]
# ['World Animals', 99.99, 121.0, 6.0]
# ['Plane', 9.99, 12.0, 1.0]
# ['Submarine Adventure', 19.99, 24.0, 2.0]
# ['Bricks and Ideas', 9.99, 123.0, nan]
# ['Basic Brick Set ', 19.99, 300.0, nan]
# ['Bricks and Eyes ', 29.23, 451.0, nan]
# ['Windows of Creativity', 29.23, 450.0, nan]
# ['Creative Fun', 34.11, 900.0, nan]
# ['Star Wars: Build Your Own Adventure Galactic Missions parts', nan, 66.0, 1.0]
# ['The Book of Bedtime Builds parts', nan, 68.0, nan]
# ['Harry Potter: Build Your Own Adventure parts', nan, 101.0, 1.0]
# ['Christmas Ideas parts', nan, 41.0, nan]
# ['Wooden Minifigure parts', nan, 29.0, nan]
# ['San Francisco', 49.99, 565.0, nan]
# ['Paris', 49.99, 649.0, nan]
# ['Trafalgar Square', 79.99, 1197.0, nan]
# ['Empire State Building', 99.99, 1767.0, nan]
# ['Burj Khalifa', 39.99, 333.0, nan]
# ['Minecraft Steve BigFig with Parrot', 14.99, 159.0, nan]
# ['Minecraft Alex BigFig with Chicken', 14.99, 160.0, nan]
# ['Minecraft Skeleton BigFig with Magma Cube', 14.99, 142.0, nan]
# ['The End Battle', 19.99, 222.0, 2.0]
# ['The Pirate Ship Adventure', 49.99, 386.0, 3.0]
# ['The Wool Farm', 19.99, 260.0, 1.0]
# ['The Blaze Bridge', 39.99, 372.0, 4.0]
# ['The Creeper Mine', 79.99, 834.0, 4.0]
# ['The Flintstones', 58.48, 748.0, 4.0]
# ['Steamboat Willie', 87.72, 751.0, 2.0]
# ['Tree House', 249.99, 3036.0, 4.0]
# ['Central Perk', 79.99, 1070.0, 7.0]
# ['Dinosaur Fossils', 59.99, 910.0, 2.0]
# ['My First Duck', nan, 6.0, nan]
# ['Town Rescue - {Random Bag}', nan, nan, nan]
# ['Town Rescue - Bird', nan, nan, nan]
# ['Town Rescue - Fireman', nan, nan, nan]
# ['Town Rescue - Cat', nan, nan, nan]
# ['Town Rescue - Policewoman', nan, nan, nan]
# ['Town Rescue - Dog', nan, nan, nan]
# ["Emmet's 'Piece' Offering", 3.99, 44.0, 1.0]
# ['Fire ATV', nan, 39.0, 1.0]
# ['Sky Police Jetpack', nan, 33.0, 2.0]
# ['Race Boat', 3.99, 34.0, 1.0]
# ['Popcorn Cart', nan, 43.0, 1.0]
# ['Space Satellite', nan, 36.0, 1.0]
# ['Naboo Starfighter', nan, 48.0, nan]
# ['Snowspeeder', nan, 49.0, nan]
# ['Minecraft Steve and Creeper Set', nan, 36.0, 2.0]
# ['Tulips', nan, 90.0, nan]
# ["Emma's Bumper Cars", 3.99, 66.0, 1.0]
# ["Mia's Water Fun", nan, 28.0, 1.0]
# ["Spider-Man's Mini Spider Crawler", nan, 73.0, 1.0]
# ['Iron Man and Dum-E', nan, 38.0, 1.0]
# ["Rex's Plantimal Ambush", 3.89, 32.0, 1.0]
# ['Podracer', nan, 58.0, nan]
# ['Lucy vs. Alien Invader', nan, 44.0, 1.0]
# ['Mini Master-Building MetalBeard', nan, 42.0, 1.0]
# ['Mini Master-Building Emmet', 3.89, 49.0, 1.0]
# ['Sam-X', nan, 56.0, nan]
# ['Ninja Workout', nan, 31.0, 1.0]
# ['Fire Flight', nan, 54.0, 1.0]
# ['Fish Free Builds - Make It Yours', nan, 39.0, nan]
# ["Elsa's Winter Throne", 3.99, 42.0, 1.0]
# ['Pelican', 3.89, 62.0, nan]
# ['Race Car', 3.99, 68.0, nan]
# ['Santa', nan, 67.0, nan]
# ['Star-Stuck Emmet', nan, 41.0, 1.0]
# ['SHAZAM!', nan, 5.0, 1.0]
# ['Obi-Wan Kenobi - Collectable Minifigure', nan, 12.0, 1.0]
# ['Futuristic Flyer', 14.61, 157.0, nan]
# ['Dune Buggy', 12.66, 147.0, nan]
# ['Deep Sea Creatures', 14.99, 230.0, nan]
# ['Sunset Track Racer', 19.99, 221.0, nan]
# ['Underwater Robot', 19.99, 207.0, nan]
# ['Shuttle Transporter', 24.36, 341.0, nan]
# ['Helicopter Adventure', 9.74, 114.0, nan]
# ['Riverside Houseboat', 29.99, 396.0, 2.0]
# ['Race Plane', 29.23, 333.0, 1.0]
# ['Fairground Carousel', 48.73, 595.0, 3.0]
# ['Twin-Rotor Helicopter', 48.73, 569.0, 1.0]
# ['Townhouse Pet Shop & Café', 79.99, 969.0, 3.0]
# ['Outback Cabin', 29.23, 305.0, 2.0]
# ['Year of the Pig', nan, 152.0, nan]
# ['MSC Cruises', nan, 181.0, nan]
# ['Jet Fighter', nan, 23.0, nan]
# ['Caterpillar', nan, 48.0, nan]
# ['Viking Ship', nan, 54.0, nan]
# ['Ladybird', nan, 27.0, nan]
# ['Crane', nan, 64.0, nan]
# ['Frog', nan, 39.0, nan]
# ['Ice Cream Truck', nan, 48.0, nan]
# ['Racing Car', nan, 50.0, nan]
# ['Eagle', nan, 56.0, nan]
# ['UFO', nan, 36.0, nan]
# ['Wolf', nan, 47.0, nan]
# ['Penguin', nan, 47.0, nan]
# ['Battle of Hoth - 20th Anniversary Edition', nan, 195.0, nan]
# ['Avengers Tower', nan, 211.0, 1.0]
# ['Space Rocket Ride', nan, 154.0, 1.0]
# ['Newbury Juice Bar', nan, 127.0, 2.0]
# ['Microscale Gingerbread House', 19.48, 499.0, nan]
# ['Christmas Tree', nan, 392.0, nan]
# ['Sea Accessories', 3.99, 24.0, nan]
# ['NINJAGO Minifigure Set', 12.99, 59.0, 4.0]
# ['Spider-Man and the Museum Break-In', 14.61, 49.0, 3.0]
# ['Summer Celebration Minifigure Pack', 12.99, 45.0, 4.0]
# ['Mars Exploration Minifigure Pack', 12.66, 44.0, 4.0]
# ['LEGOLAND® Park', nan, 1336.0, 11.0]
# ['LEGOLAND® Driving School Cars', nan, 209.0, 4.0]
# ['Birthday Clown', 9.99, 150.0, nan]
# ["Valentine's Puppy", 9.99, 147.0, nan]
# ['Easter Chick', 9.99, 120.0, nan]
# ['Halloween Ghost', 9.74, 136.0, nan]
# ['Thanksgiving Scarecrow', 9.99, 177.0, nan]
# ['Reindeer, Elf and Elfie', 19.99, 281.0, nan]
# ['Dragon Dance Guy', 9.99, 170.0, nan]
# ['LEGO House Exclusive Minifigure 2019', nan, 7.0, 1.0]
# ['LEGO Store Picture Frame', 14.99, 170.0, 1.0]
# ['Name Sign', 9.99, 91.0, nan]
# ["Olaf's Traveling Sleigh", nan, 97.0, 1.0]
# ['Battle of Endor', nan, 197.0, nan]
# ['LEGO House Dinosaurs', nan, 864.0, nan]
# ['Lady Liberty', 9.99, 153.0, nan]
# ['Xmas Accessories', 3.99, 32.0, 1.0]
# ['Rebuild the World minifigure', nan, 6.0, nan]
# ['1989 Batmobile - Limited Edition', nan, 366.0, nan]
# ['Reindeer', nan, 77.0, nan]
# ['Plants from Plants', nan, 29.0, nan]
# ["Jasmine's Petite Tower", 9.99, 49.0, 1.0]
# ["Cinderella's Carriage Ride", 19.99, 91.0, 1.0]
# ["Ariel's Castle", 24.99, 115.0, 1.0]
# ["Aladdin's and Jasmine's Palace Adventures", 29.99, 193.0, 2.0]
# ["Ariel, Aurora, and Tiana's Royal Celebration", 44.99, 282.0, 3.0]
# ["Rapunzel's Small Tower", 9.99, 44.0, 1.0]
# ['Enchanted Treehouse', 48.73, 302.0, 3.0]
# ["Anna's Canoe Expedition", 19.99, 108.0, 2.0]
# ['Elsa and the Reindeer Carriage', 29.99, 116.0, 1.0]
# ['Arendelle Castle Village', 79.99, 521.0, 3.0]
# ["Elsa's Jewellery Box Creation", 39.99, 300.0, 1.0]
# ['Olaf', 14.61, 122.0, nan]
# ['Underwater Loop', 29.23, 389.0, 2.0]
# ["Andrea's Heart Box", 7.99, 84.0, 1.0]
# ["Emma's Heart Box", 7.99, 85.0, 1.0]
# ["Stephanie's Heart Box", 7.99, 85.0, 1.0]
# ["Olivia's Heart Box", 7.99, 85.0, 2.0]
# ["Mia's Heart Box", 7.99, 83.0, 1.0]
# ['Heart Box Friendship Pack', 19.99, 199.0, 2.0]
# ["Emma's Mobile Veterinary Clinic ", 9.74, 50.0, 1.0]
# ["Mia's Foal Stable ", 19.49, 118.0, 1.0]
# ['Heartlake City Supermarket', 29.23, 140.0, 2.0]
# ["Mia's Forest Adventure", 14.99, 134.0, 1.0]
# ["Stephanie's Buggy & Trailer ", 19.99, 166.0, 1.0]
# ["Emma's Art Studio", 24.99, 235.0, 2.0]
# ["Olivia's Cupcake Cafe", 29.23, 335.0, 2.0]
# ["Stephanie's Horse Jumping", 38.98, 337.0, 2.0]
# ["Andrea's Talent Show", 49.99, 492.0, 2.0]
# ["Mia's House", 68.23, 715.0, 3.0]
# ["Mia's Horse Trailer", 29.23, 216.0, 2.0]
# ["Stephanie's Gymnastics Show", 29.23, 241.0, 2.0]
# ['Funny Octopus Ride', 38.98, 324.0, 2.0]
# ["Andrea's Pool Party", 48.73, 468.0, 2.0]
# ['Heartlake City Amusement Pier', 126.71, 1251.0, 7.0]
# ['Turtles Rescue Mission', 19.49, 225.0, 2.0]
# ['Dolphins Rescue Mission', 38.98, 363.0, 2.0]
# ['Heartlake City Restaurant', 58.48, 624.0, 3.0]
# ['Lighthouse Rescue Centre', 58.48, 602.0, 2.0]
# ['Rescue Mission Boat', 87.72, 908.0, 4.0]
# ['LEGO Friends Advent Calendar', 24.99, 330.0, 3.0]
# ["Olivia's Hamster Playground", 9.74, 81.0, 1.0]
# ["Andrea's Summer Heart Box", 7.99, 83.0, 1.0]
# ["Emma's Summer Heart Box", 7.99, 86.0, 1.0]
# ["Stephanie's Summer Heart Box", 7.99, 95.0, 1.0]
# ["Olivia's Summer Heart Box", 7.99, 93.0, 2.0]
# ["Mia's Summer Heart Box", 7.99, 85.0, 1.0]
# ['Emmet', nan, 113.0, nan]
# ['Wyldstyle', nan, 134.0, nan]
# ['Benny', nan, 103.0, nan]
# ['Sweet Mayhem', nan, 137.0, nan]
# ['Cherry Picker', 9.74, 155.0, nan]
# ['Power Boat', 14.99, 174.0, nan]
# ['Getaway Truck', 19.99, 128.0, nan]
# ['Police Pursuit', 19.49, 120.0, nan]
# ['Rescue Helicopter', 29.99, 325.0, nan]
# ['Chevrolet Corvette ZR1', 39.99, 579.0, nan]
# ['Tracked Loader', 59.99, 827.0, nan]
# ['Remote-Controlled Stunt Racer', 79.99, 324.0, nan]
# ['Porsche 911 RSR', 199.99, 1580.0, nan]
# ['Compact Crawler Crane', 87.72, 920.0, nan]
# ['Car Transporter', 149.99, 2493.0, nan]
# ['4x4 X-Treme Off-Roader', 229.99, 958.0, nan]
# ['Liebherr R 9800', 449.99, 4108.0, nan]
# ['Land Rover Defender', 199.99, 2573.0, nan]
# ["Elsa's Ice Palace", 69.99, 701.0, 7.0]
# ['City Shaper Challenge Kit', nan, 2238.0, 1.0]
# ['BOOMTOWN BUILD Inspire Set', nan, 739.0, nan]
# ['BOOMTOWN BUILD Discovery Set', nan, 78.0, 4.0]
# ['Ski Resort', 77.97, 806.0, 11.0]
# ['Jet Patrol', 9.74, 54.0, 2.0]
# ['Sky Police Drone Chase', 19.49, 192.0, 3.0]
# ['Parachute Arrest', 29.23, 218.0, 4.0]
# ['Diamond Heist', 49.99, 400.0, 4.0]
# ['Air Base', 73.1, 529.0, 6.0]
# ['Barbecue Burn Out', 9.74, 64.0, 2.0]
# ['Dock Side Fire', 14.61, 97.0, 2.0]
# ['Burger Bar Fire Rescue', 29.99, 327.0, 3.0]
# ['Fire Station', 59.99, 509.0, 4.0]
# ['Downtown Fire Brigade', 99.99, 943.0, 7.0]
# ['Fire Plane', 38.98, 363.0, 3.0]
# ['Desert Rally Racer', 9.99, 75.0, 1.0]
# ['Construction Loader', 9.99, 88.0, 1.0]
# ['Garbage Truck', 19.99, 90.0, 2.0]
# ['Diving Yacht', 19.99, 148.0, 2.0]
# ['Snow Groomer', 19.49, 197.0, 2.0]
# ['Harvester Transport', 29.99, 358.0, 3.0]
# ['Satellite Service Mission', 9.74, 84.0, 1.0]
# ['Rover Testing Drive', 19.49, 202.0, 2.0]
# ['Mars Research Shuttle', 29.99, 273.0, 2.0]
# ['Lunar Space Station', 48.73, 412.0, 5.0]
# ['Deep Space Rocket and Launch Control', 99.99, 837.0, 7.0]
# ['Rocket Assembly & Transport', 129.99, 1055.0, 8.0]
# ['People Pack - Space Research and Development', 38.98, 209.0, 15.0]
# ['Fire Chief Response Truck', 19.49, 201.0, 2.0]
# ['Garage Centre', 38.98, 234.0, 4.0]
# ['Donut Shop Opening', 79.99, 790.0, 10.0]
# ['People Pack - Fun Fair', 38.98, 183.0, 14.0]
# ['LEGO City Advent Calendar', 19.99, 234.0, 8.0]
# ['Straight & T-Junction ', 9.74, 2.0, nan]
# ['Curves & Crossroad', 9.74, 2.0, nan]
# ['Police Patrol Car', 9.99, 92.0, 1.0]
# ['Kayak Adventure', 9.99, 84.0, 1.0]
# ['Super Pack 3-in-1', nan, nan, nan]
# ['Super Pack 2-in-1 ', nan, nan, nan]
# ['Super Pack 2-in-1 ', nan, nan, nan]
# ['Bonus/Value pack', nan, 218.0, nan]
# ['Bonus/Value pack', nan, 125.0, nan]
# ['2-in-1 Value Pack: Star-Lord & Gamora', nan, 249.0, nan]
# ['Super Pack 3-in-1', nan, nan, nan]
# ['Super Pack 3-in-1', nan, nan, nan]
# ['Super Pack 3-in-1', nan, nan, nan]
# ["J.B.'s Ghost Lab", 19.99, 174.0, 3.0]
# ['Wrecked Shrimp Boat', 29.23, 310.0, 4.0]
# ['Graveyard Mystery', 29.23, 335.0, 4.0]
# ["El Fuego's Stunt Truck", 38.98, 428.0, 4.0]
# ['Shrimp Shack Attack', 48.73, 579.0, 5.0]
# ['Paranormal Intercept Bus 3000', 58.48, 689.0, 5.0]
# ['Ghost Train Express', 77.97, 698.0, 6.0]
# ['Newbury Haunted High School', 116.97, 1474.0, 8.0]
# ['Spinjitzu Kai', 9.99, 97.0, 1.0]
# ['Spinjitzu Jay', 9.99, 97.0, 1.0]
# ['Spinjitzu Zane', 9.99, 109.0, 1.0]
# ['Spinjitzu Cole', 9.99, 117.0, 1.0]
# ['Spinjitzu Nya & Wu', 19.99, 227.0, 2.0]
# ['Spinjitzu Lloyd vs. Garmadon', 19.99, 208.0, 2.0]
# ['The Samurai Mech', 14.61, 154.0, 3.0]
# ['The Golden Dragon', 19.49, 171.0, 3.0]
# ["Kai's Blade Cycle & Zane's Snowmobile", 29.99, 376.0, 4.0]
# ["Jay's Storm Fighter", 38.98, 490.0, 4.0]
# ["Cole's Earth Driller ", 49.99, 587.0, 4.0]
# ['Monastery of Spinjitzu', 77.97, 1070.0, 8.0]
# ["Lloyd's Journey", 14.61, 81.0, 2.0]
# ["Cole's Dirt Bike", 19.49, 212.0, 3.0]
# ['Shuricopter', 29.23, 361.0, 3.0]
# ['Fire Fang', 43.86, 463.0, 4.0]
# ['Katana 4X4', 48.73, 450.0, 5.0]
# ["Lloyd's Titan Mech", 68.23, 876.0, 6.0]
# ['Land Bounty', 126.71, 1178.0, 9.0]
# ['Castle of the Forsaken Emperor', 97.47, 1218.0, 7.0]
# ['The Ultra Dragon', 87.72, 951.0, 6.0]
# ['Monastery Training', 9.99, 122.0, 2.0]
# ['Spinjitzu Slam - Lloyd', 9.74, 70.0, 1.0]
# ['Spinjitzu Slam - Jay', 9.74, 72.0, 1.0]
# ['Spinjitzu Slam - Zane', 9.99, 63.0, 1.0]
# ['Spinjitzu Slam - Kai vs. Samurai', 19.49, 164.0, 2.0]
# ['LEGO Movie Maker', 49.99, 482.0, 6.0]
# ["Emmet and Benny's 'Build and Fix' Workshop!", 19.99, 117.0, 2.0]
# ["Unikitty's Sweetest Friends EVER!", 9.99, 76.0, 3.0]
# ["Emmet's Thricycle!", 14.99, 174.0, 1.0]
# ["Introducing Queen Watevra Wa'Nabi", 19.99, 115.0, 4.0]
# ["Queen Watevra's Build Whatever Box!", 39.99, 455.0, nan]
# ["Rex's Rex-treme Offroader!", 29.99, 236.0, 2.0]
# ['Ultrakatty & Warrior Lucy!', 29.99, 348.0, 2.0]
# ['Pop-Up Party Bus', 89.99, 1024.0, 4.0]
# ["Emmet and Lucy's Escape Buggy!", 49.99, 550.0, 4.0]
# ["Sweet Mayhem's Systar Starship!", 69.99, 502.0, 3.0]
# ["Emmet's Dream House/Rescue Rocket!", 59.99, 706.0, 4.0]
# ["Emmet's Builder Box!", 29.99, 125.0, 1.0]
# ["Lucy's Builder Box!", 29.99, 141.0, 2.0]
# ["MetalBeard's Heavy Metal Motor Trike!", 59.99, 461.0, 2.0]
# ["Rex's Rexplorer!", 119.99, 1187.0, 2.0]
# ['Battle-Ready Batman and MetalBeard', 19.99, 168.0, 2.0]
# ['Shimmer & Shine Sparkle Spa!', 69.99, 691.0, 8.0]
# ["Queen Watevra's 'So-Not-Evil' Space Palace", 99.99, 995.0, 5.0]
# ['The Rexcelsior!', 149.99, 1826.0, 4.0]
# ['Welcome to Apocalypseburg!', 299.99, 3178.0, 13.0]
# ["Benny's Space Squad", 9.99, 68.0, 5.0]
# ["Emmet's Triple-Decker Couch Mech", 29.99, 312.0, 3.0]
# ['Good Morning Sparkle Babies!', 9.99, 50.0, 4.0]
# ['Systar Party Crew', 19.99, 196.0, 2.0]
# ['Wyld-Mayhem Star Fighter', 49.99, 405.0, 4.0]
# ['LEGO Minifigures - The LEGO Movie 2 Series {Random bag}', nan, nan, nan]
# ['Awesome Remix Emmet', nan, 7.0, 1.0]
# ['Battle-Ready Lucy', nan, 8.0, 1.0]
# ['Apocalypse Benny', nan, 8.0, 1.0]
# ['Giraffe Guy', nan, 6.0, 1.0]
# ['Crayon Girl', nan, 6.0, 1.0]
# ['Sherry Scratchen-Post & Scarfield', nan, 6.0, 1.0]
# ['Hula Lula', nan, 8.0, 1.0]
# ['Watermelon Dude', nan, 6.0, 1.0]
# ['Flashback Lucy', nan, 7.0, 1.0]
# ['Swamp Creature', nan, 6.0, 1.0]
# ['Candy Rapper', nan, 8.0, 1.0]
# ["Gone Golfin' President Business", nan, 6.0, 1.0]
# ['Apocalypseburg Abe', nan, 7.0, 1.0]
# ['Vest Friend Rex', nan, 6.0, 1.0]
# ['Kitty Pop', nan, 7.0, 1.0]
# ['Dorothy Gale & Toto', nan, 7.0, 1.0]
# ['Cowardly Lion', nan, 6.0, 1.0]
# ['Scarecrow', nan, 6.0, 1.0]
# ['Tin Man', nan, 8.0, 1.0]
# ['Unikitty', nan, 15.0, 1.0]
# ['LEGO Minifigures - The LEGO Movie 2 Series - Complete', nan, 144.0, 20.0]
# ['LEGO Minifigures - The LEGO Movie 2 Series - Sealed Box', 3.99, nan, nan]
# ['LEGO Minifigures - Disney Series 2 {Random bag}', nan, nan, nan]
# ['Vintage Mickey', 3.99, 6.0, 1.0]
# ['Vintage Minnie', 3.99, 7.0, 1.0]
# ['Huey Duck', 3.99, 7.0, 1.0]
# ['Dewey Duck', 3.99, 7.0, 1.0]
# ['Louie Duck', 3.99, 8.0, 1.0]
# ['Scrooge McDuck', 3.99, 8.0, 1.0]
# ['Chip', 3.99, 6.0, 1.0]
# ['Dale', 3.99, 5.0, 1.0]
# ['Elsa', 3.99, 7.0, 1.0]
# ['Anna', 3.99, 8.0, 1.0]
# ['Jafar', 3.99, 8.0, 1.0]
# ['Jasmine', 3.99, 6.0, 1.0]
# ['Hades', 3.99, 6.0, 1.0]
# ['Hercules', 3.99, 8.0, 1.0]
# ['Sally', 3.99, 7.0, 1.0]
# ['Jack Skellington', 3.99, 10.0, 1.0]
# ['Edna Mode', 3.99, 8.0, 1.0]
# ['Frozone', 3.99, 7.0, 1.0]
# ['LEGO Minifigures - Disney Series 2 - Complete', nan, 129.0, 18.0]
# ['LEGO Minifigures - Disney Series 2 - Sealed Box', 3.99, nan, nan]
# ['LEGO Minifigures - Series 19 {Random Bag}', nan, nan, nan]
# ['Video Game Champ', nan, 7.0, 1.0]
# ['Shower Guy', nan, 8.0, 1.0]
# ['Fright Knight', nan, 9.0, 1.0]
# ['Monkey King', nan, 12.0, 1.0]
# ['Programmer', nan, 10.0, 1.0]
# ['Mummy Queen', nan, 6.0, 1.0]
# ['Jungle Explorer', nan, 8.0, 1.0]
# ['Fire Fighter', nan, 6.0, 1.0]
# ['Dog Sitter', nan, 9.0, 1.0]
# ['Pizza Costume Guy', nan, 6.0, 1.0]
# ['Galactic Bounty Hunter', nan, 8.0, 1.0]
# ['Gardener', nan, 7.0, 1.0]
# ['Rugby Player', nan, 6.0, 1.0]
# ['Fox Costume Girl', nan, 8.0, 1.0]
# ['Bear Costume Guy', nan, 7.0, 1.0]
# ['Mountain Biker', nan, 10.0, 1.0]
# ['LEGO Minifigures - Series 19 - Complete', 3.99, 127.0, 16.0]
# ['LEGO Minifigures - Series 19 - Sealed Box', nan, nan, nan]
# ['Disney Train and Station', 329.99, 2925.0, 5.0]
# ['Naboo Starfighter Microfighter', 9.99, 62.0, 1.0]
# ['Sith Infiltrator Microfighter', 9.99, 92.0, 1.0]
# ['Elite Praetorian Guard Battle Pack', 14.99, 109.0, 5.0]
# ['Inferno Squad Battle Pack', 14.99, 118.0, 4.0]
# ['Darth Vader Bust', nan, 327.0, nan]
# ['Escape Pod vs. Dewback Microfighters', 19.99, 177.0, 3.0]
# ['Death Star Escape', 29.99, 329.0, 4.0]
# ['Kylo Ren & Sith Trooper', 19.99, 240.0, nan]
# ['Droid Gunship', 59.99, 389.0, 4.0]
# ['AT-AP Walker', 68.23, 689.0, 5.0]
# ['X-wing Starfighter Trench Run', 29.23, 132.0, 3.0]
# ['Duel on Starkiller Base', 19.99, 191.0, 2.0]
# ['TIE Fighter Attack', 19.99, 77.0, 2.0]
# ['Action Battle Endor Assault', 29.23, 193.0, 2.0]
# ['Action Battle Hoth Generator Attack', 29.23, 235.0, 2.0]
# ["Major Vonreg's TIE Fighter", 68.23, 496.0, 4.0]
# ['Action Battle Echo Base Defense', 58.48, 504.0, 6.0]
# ['Black Ace TIE Interceptor', 48.73, 396.0, 3.0]
# ['Slave I - 20th Anniversary Edition', 116.97, 1007.0, 5.0]
# ['Tantive IV', 194.95, 1768.0, 6.0]
# ['LEGO Star Wars Advent Calendar', 29.99, 280.0, 9.0]
# ['Death Star Cannon', 19.49, 159.0, 2.0]
# ['Rebel A-wing Starfighter', 14.99, 62.0, 2.0]
# ['Resistance A-wing Starfighter', 29.23, 269.0, 2.0]
# ['Resistance Y-wing Starfighter', 69.99, 578.0, 5.0]
# ['Pasaana Speeder Chase', 48.73, 373.0, 4.0]
# ["Darth Vader's Castle", 129.99, 1060.0, 6.0]
# ['Imperial Star Destroyer', 699.99, 4784.0, 2.0]
# ['Droid Commander', 194.95, 1177.0, nan]
# ['AT-ST Raider', 59.99, 540.0, 4.0]
# ['Yoda', 119.99, 1771.0, 1.0]
# ["Kylo Ren's Shuttle", 119.99, 1005.0, 6.0]
# ['Millennium Falcon', 169.99, 1351.0, 7.0]
# ["Anakin's Podracer – 20th Anniversary Edition", 29.23, 279.0, 3.0]
# ['Snowspeeder – 20th Anniversary Edition', 39.99, 309.0, 4.0]
# ['Clone Scout Walker – 20th Anniversary Edition', 29.99, 250.0, 5.0]
# ['Imperial Dropship – 20th Anniversary Edition', 19.99, 125.0, 5.0]
# ['Mini Boost Droid Commander', nan, 62.0, 3.0]
# ['The Upside Down', 199.99, 2287.0, 8.0]
# ['Ferrari F40 Competizione', 14.99, 198.0, 1.0]
# ['Chevrolet Camaro ZL1 Race Car', 14.99, 198.0, 1.0]
# ['McLaren Senna', 14.99, 219.0, 1.0]
# ['2018 Dodge Challenger SRT Demon and 1970 Dodge Charger R/T', 39.99, 478.0, 3.0]
# ['1967 Mini Cooper S Rally and 2018 MINI John Cooper Works Buggy', 48.73, 481.0, 4.0]
# ['1974 Porsche 911 Turbo 3.0', 14.99, 180.0, 1.0]
# ['Dilophosaurus on the Loose', 24.36, 168.0, 3.0]
# ['Baryonyx Face-Off: The Treasure Hunt', 59.99, 434.0, 4.0]
# ['Jurassic Park: T. rex Rampage', 249.99, 3120.0, 6.0]
# ['Triceratops Rampage', 58.48, 447.0, 4.0]
# ['T. rex vs Dino-Mech Battle', 87.72, 716.0, 4.0]
# ['Expecto Patronum', 19.49, 121.0, 4.0]
# ['Hungarian Horntail Triwizard Challenge', 34.11, 265.0, 4.0]
# ["Hagrid's Hut: Buckbeak's Rescue", 59.99, 496.0, 6.0]
# ['Hogwarts Clock Tower', 99.99, 922.0, 8.0]
# ['The Knight Bus', 39.99, 403.0, 3.0]
# ["Beauxbatons' Carriage: Arrival at Hogwarts ", 48.73, 430.0, 4.0]
# ['LEGO Harry Potter Advent Calendar', 24.99, 305.0, 8.0]
# ['The Rise of Voldemort', 19.49, 184.0, 6.0]
# ['Tracer vs. Widowmaker', 14.99, 129.0, 2.0]
# ['Hanzo vs. Genji', 24.36, 197.0, 3.0]
# ['Dorado Showdown', 29.99, 419.0, 3.0]
# ['D.Va & Reinhardt', 39.99, 455.0, 2.0]
# ['Bastion', 58.48, 602.0, nan]
# ['Watchpoint: Gibraltar', 87.72, 730.0, 4.0]
# ['Wrecking Ball', 19.49, 227.0, 1.0]
# ['Junkrat & Roadhog', 48.73, 380.0, 2.0]
# ['Spider-Man Bike Rescue', 24.36, 235.0, 3.0]
# ["Spider-Man's Spider Crawler", 38.98, 418.0, 4.0]
# ['Spider Mech vs. Venom', 48.73, 604.0, 4.0]
# ['Batman Batsub and the Underwater Clash', 24.99, 174.0, 3.0]
# ['Batman Mech vs. Poison Ivy Mech ', 39.99, 375.0, 4.0]
# ['Mr. Freeze Batcycle Battle', 24.36, 200.0, 3.0]
# ['Batmobile: Pursuit of The Joker', 29.23, 342.0, 2.0]
# ['Batwing and The Riddler Heist', 48.73, 489.0, 4.0]
# ['Batcave Clayface Invasion', 97.47, 1038.0, 6.0]
# ['Captain America: Outriders Attack', 24.36, 167.0, 4.0]
# ['War Machine Buster', 34.11, 362.0, 4.0]
# ['Iron Man Hall of Armor', 59.99, 524.0, 6.0]
# ['Avengers Ultimate Quinjet', 77.97, 838.0, 6.0]
# ['Captain Marvel and The Skrull Attack', 29.23, 307.0, 3.0]
# ['Molten Man Battle', 29.23, 294.0, 3.0]
# ['Hydro-Man Attack', 39.99, 471.0, 4.0]
# ['Stark Jet and the Drone Attack', 58.48, 504.0, 4.0]
# ['Avengers Compound Battle', 97.47, 699.0, 7.0]
# ['Spider-Man Car Chase', 9.99, 52.0, 2.0]
# ['Spider-Man: Doc Ock Diamond Heist', 29.99, 150.0, 3.0]
# ['Batman vs. The Riddler Robbery', 9.74, 59.0, 2.0]
# ['Batman and The Joker Escape', 38.98, 171.0, 4.0]
# ['1989 Batmobile', 249.99, 3306.0, 3.0]
# ['Avengers Hulk Helicopter Rescue', 58.48, 482.0, 5.0]
# ['Sith Trooper Bust', nan, 484.0, nan]
# ['Captain Marvel and the Asis', nan, 271.0, 2.0]
# ['The Dark Knight of Gotham City', nan, 427.0, 1.0]
# ["Chinese New Year's Eve Dinner", nan, 615.0, 6.0]
# ['Dragon Dance', nan, 622.0, 5.0]
# ['Dragon Boat Race', 49.99, 643.0, 15.0]
# ['Koi', nan, 293.0, nan]
# ['Shark Skin', nan, 31.0, nan]
# ['Splash Koi Skin', nan, 33.0, nan]
# ['Ink Koi Skin', nan, 33.0, nan]
# ['Boost Hub', 79.99, 1.0, nan]
# ['Colour & Distance Sensor', 13.99, 1.0, nan]
# ['Medium Linear Motor', 16.99, 1.0, nan]
# ['Train Motor', 13.99, 7.0, nan]
# ['Garmadon', nan, 10.0, 1.0]
# ['Garmadon', nan, 10.0, 1.0]
# ['Wu', nan, 1.0, 1.0]
# ['Wu', nan, 1.0, 1.0]
# ['Kai vs. Wyplash', nan, 13.0, 2.0]
# ['Kai vs. Wyplash', nan, 13.0, 2.0]
# ['Jay Vs. Lasha', nan, 12.0, 2.0]
# ['Jay vs. Lasha', nan, 12.0, 2.0]
# ['Baby Raptor', nan, 33.0, nan]
# ['Owen with Baby Raptor', nan, 7.0, 1.0]
# ['Batman with Batarang', nan, 7.0, 1.0]
# ['Robin', nan, 7.0, 1.0]
# ['Superman', nan, 8.0, 1.0]
# ['The Flash', nan, 6.0, 1.0]
# ['Joker', nan, 9.0, 1.0]
# ['Batman', nan, 6.0, 1.0]
# ['Show Jump', nan, 34.0, nan]
# ['Emmet with Tools', nan, 9.0, 1.0]
# ['Rex with Jetpack', nan, nan, 1.0]
# ["Emma's Kitty Chico", nan, 22.0, nan]
# ['Shop with Costumes', nan, 30.0, nan]
# ['Sweet Baby', nan, 15.0, 1.0]
# ["Bear's Cave", nan, 22.0, nan]
# ["Andrea's Booth with Waffles", nan, 29.0, nan]
# ['Robot on paddleboard', nan, 18.0, 1.0]
# ['Ice Cream Parlour', nan, 38.0, nan]
# ["Andrea's Stage", nan, 21.0, nan]
# ["Stephanie's Puppy Dash", nan, 20.0, nan]
# ['Halloween Store', nan, 15.0, nan]
# ["Olivia's Bakery", nan, 38.0, nan]
# ['Jack', nan, 8.0, 1.0]
# ['Possessed Pizza Delivery Man', nan, 6.0, 1.0]
# ['Parker', nan, 6.0, 1.0]
# ['TLM2 Accessory Set 2019', 12.99, 48.0, 4.0]
# ['Oni Battle Pack', 12.99, 36.0, 3.0]
# ['Emmet Key Chain', 4.86, nan, nan]
# ['Lucy Key Chain', 4.99, nan, nan]
# ["Emmet's Construction Worker Vest", 14.99, nan, nan]
# ['Batarang', 7.79, nan, nan]
# ['Flail', nan, nan, nan]
# ['Emmet Mask', 9.99, nan, nan]
# ['Lucy Hair', 4.99, nan, nan]
# ['Emmet Pod', 8.99, 27.0, 1.0]
# ["Sweet Mayhem's Disco Pod", 8.76, 28.0, 1.0]
# ['TLM2 Tumbler with Straw', 7.99, nan, nan]
# ['TLM2 Hydration Bottle', 12.99, nan, nan]
# ['TLM2 Notebook', 12.99, nan, nan]
# ['Emmet Plush', 24.99, nan, nan]
# ['Lucy Plush', 24.36, nan, nan]
# ['Friends Creative Bag Charms', 5.99, nan, nan]
# ['Stephanie Key Chain', 4.99, nan, nan]
# ['Olivia Key Chain', 4.99, nan, nan]
# ['Friends Phone Cover', 24.99, nan, nan]
# ['Friends Tumbler with Straw', 7.79, nan, nan]
# ['Cookie Cutters', 9.74, nan, nan]
# ['LEGO Friends Ceramic Mug', 14.99, nan, nan]
# ['LEGO Friends Hair Accessory Set', 9.99, nan, nan]
# ['Jay Keyring', 4.86, nan, nan]
# ['Nya Keyring', 4.86, nan, nan]
# ["Lloyd's Kendo Training Pod", 8.99, 25.0, 1.0]
# ['4 4x4 Magnets', 7.79, nan, nan]
# ['NINJAGO Tumbler with Straw', 7.99, nan, nan]
# ['Creative Bag Charm', 5.99, nan, nan]
# ['Brick Suit Guy Key Chain', 4.86, nan, nan]
# ['Cactus Boy Key Chain', 5.99, nan, nan]
# ['Elephant Girl Key Chain', 4.99, nan, nan]
# ['LEGO Greeting Card', 4.99, 40.0, 1.0]
# ['LEGO Toy Soldier Ornament', 7.99, 43.0, nan]
# ['Drinking cup', nan, nan, nan]
# ['LEGO® Minifigure Ceramic Mug', 14.99, nan, nan]
# ['LEGO Brick Ice Cube Tray', 9.74, nan, nan]
# ['Ice Lollipop Tray', nan, nan, nan]
# ['LEGO Key Hanger', 9.74, nan, nan]
# ['London Bus Magnet', 9.99, nan, nan]
# ['4 4x4 Magnets', 7.79, nan, nan]
# ['Creative Stationery Set', 16.99, nan, nan]
# ['City Firefighter Key Chain', 4.99, nan, nan]
# ['City Police Vest', nan, nan, nan]
# ['LEGO DUPLO Tableware', 14.61, nan, nan]
# ['Brick Stickers', 5.99, 17.0, nan]
# ['Creative Rings', nan, 43.0, nan]
# ['Stormtrooper Keyring', 5.99, nan, nan]
# ['Luke Skywalker Key Chain', 4.99, nan, nan]
# ['Princess Leia Key Chain', 4.99, nan, nan]
# ['Kylo Ren Key Chain', 4.86, nan, nan]
# ['Spider Man Key Chain', 5.99, nan, nan]
# ['Batman Key Chain', 5.99, nan, nan]
# ['Superman Key Chain', 5.99, nan, nan]
# ['Batwoman Key Chain', 5.99, nan, nan]
# ['Ariel Key Chain', 4.99, nan, nan]
# ['Aurora Key Chain', 4.99, nan, nan]
# ['Creeper Key Chain', 4.99, nan, nan]
# ['Chicken Skater Pod', nan, 36.0, 1.0]
# ['2x6 Key Chain', 4.99, nan, nan]
# ['TLM2 Stop Sign Shield', 15.99, nan, nan]
# ['Wooden Minifigure', 116.97, nan, nan]
# ['Wooden Minifigure, Colette Mon Amour Edition', nan, nan, nan]
# ['Elsa Key Chain', 5.99, nan, nan]
# ['Anna Key Chain', 5.99, nan, nan]
# ['Olaf Key Chain', 4.99, nan, nan]
# ['Minifigure Factory Box', nan, nan, nan]
# ['Young Wu', nan, 9.0, 1.0]
# ['Jay', nan, 8.0, 1.0]
# ['Heavy Metal', nan, 11.0, 1.0]
# ['Iron Baron', nan, 7.0, 1.0]
# ['Lloyd', nan, 10.0, 1.0]
# ['Daddy No Legs', nan, 28.0, 1.0]
# ['Nya', nan, 9.0, 1.0]
# ['Blizzard Samurai', nan, 9.0, 1.0]
# ['Cole', nan, 14.0, 1.0]
# ['Pyro Whipper', nan, 8.0, 1.0]
# ['Kai', nan, 10.0, 1.0]
# ['Blizzard Samurai', nan, 8.0, 1.0]
# ['Zane', nan, 8.0, 1.0]
# ['Jay', nan, 9.0, 1.0]
# ['Luke Skywalker', nan, 6.0, 1.0]
# ['Resistance Bomber', nan, 37.0, nan]
# ['Slave I', nan, 31.0, nan]
# ['U-wing', nan, 37.0, nan]
# ['IG-88', nan, 11.0, 1.0]
# ['AT-M6', nan, 52.0, nan]
# ['Millennium Falcon', nan, 32.0, nan]
# ['B-wing', nan, 52.0, nan]
# ['First Order Stormtrooper ', nan, 5.0, 1.0]
# ['Jedi Interceptor', nan, 30.0, nan]
# ['First Order SF TIE Fighter', nan, 32.0, nan]
# ["Kylo Ren's TIE Silencer", nan, 33.0, nan]
# ['Police Officer and Jet', nan, 22.0, 1.0]
# ['Fireman', nan, 9.0, 1.0]
# ['Lawnmower', nan, 27.0, 1.0]
# ['Police Officer with Jetpack', nan, 10.0, 1.0]
# ['Gyrocopter', nan, 29.0, 1.0]
# ['Diver', nan, 16.0, 1.0]
# ['Police Buggy', nan, 27.0, 1.0]
# ['Astronaut', nan, 18.0, 2.0]
# ['Pizza Delivery Biker', nan, 10.0, 1.0]
# ['Traffic Cop', nan, 9.0, 1.0]
# ['Space Buggy', nan, 17.0, 1.0]
# ['Lumberjack', nan, 13.0, 1.0]
# ['FIRST Competitions Medal', nan, 18.0, nan]
# ['Spike Prime Marketing Kit', nan, 150.0, nan]
# ['BOOMTOWN BUILD Discover More', nan, 12.0, nan]
# ['Butterfly', nan, 45.0, nan]
# ['LEGO System House', nan, 985.0, nan]
# ['LEGO Play Day polybag', nan, 39.0, 5.0]
# ['Christmas X-wing', nan, 1038.0, 3.0]
# ['Reusable Bag', nan, nan, nan]
# ['Yoda Minifigure Link Watch', nan, nan, nan]
# ['2x4 Red Luggage Tag', 4.99, nan, nan]
# ['2x4 Blue Luggage Tag', 4.99, nan, nan]
# ['LEGO Pencils 6 pack', 3.99, nan, nan]
# ['Building a Dream - The Story of the LEGO House', nan, nan, nan]
# ['Emma Buildable Watch', nan, nan, nan]
# ['Boy Luggage Tag', 7.99, nan, nan]
# ['Storage Bag', nan, nan, nan]
# ['Emmet Alarm Clock', 29.99, nan, nan]
# ['Wyldstyle Alarm Clock', 29.23, nan, nan]
# ['Emmet Minifigure Link Watch', 24.99, nan, nan]
# ['Unikitty Buildable Watch with Figure Link', 24.99, nan, nan]
# ['Wyldstyle Minifigure Link Watch', 24.36, nan, nan]
# ['Hot Dog Guy Key Light', 12.99, nan, nan]
# ['Banana Guy Key Light', 12.99, nan, nan]
# ['Batman Luggage Tag', 7.99, nan, nan]
# ['Emmet Luggage Tag', 7.99, nan, nan]
# ['Sweet Mayhem Luggage Tag', 7.99, nan, nan]
# ['Unikitty Luggage Tag', 7.99, nan, nan]
# ['Unikitty Night Light', 34.99, nan, nan]
# ['THE LEGO MOVIE 2 Sticker Roll', 3.99, nan, nan]
# ['Batman Key Light', 12.99, nan, nan]
# ['Emmet Key Light', 12.99, nan, nan]
# ['Unikitty Key Light', 12.99, nan, nan]
# ['Boy NiteLite', nan, nan, nan]
# ['Girl NiteLite', nan, nan, nan]
# ['Unikitty Torch', nan, nan, nan]
# ['Bag Tag', nan, nan, nan]
# ['Lunch Set Iconic Girl', nan, nan, nan]
# ['The LEGO Movie 2 Awesome Trading Cards', nan, nan, nan]
# ['The LEGO Movie 2 Awesome Collector Album', nan, nan, nan]
# ['Holographic Brick Backpack', nan, nan, nan]
# ['Boba Fett Bag Tag', 7.99, nan, nan]
# ['Darth Vader Bag Tag', 7.99, nan, nan]
# ['R2 D2 Bag Tag', 7.99, nan, nan]
# ['Yoda Bag Tag', nan, nan, nan]
# ['Exclusive LEGO Ford Mustang Key Chain', nan, nan, nan]
# ['20th Anniversary Darth Vader Brick Clock', 29.99, nan, nan]
# ['20th Anniversary Darth Vader Link Watch', 24.99, nan, nan]
# ['Stormtrooper Bag Tag', 7.99, nan, nan]
# ['Emmet Clip', nan, nan, nan]
# ['Unikitty Clip', nan, nan, nan]
# ['LEGO Star Wars Notebook with Gel Pen', 17.99, nan, nan]
# ['Sweet Mayhem Clip', nan, nan, nan]
# ['Benny Clip', nan, nan, nan]
# ['Emmet Minifigure Plush', nan, nan, nan]
# ['Unikitty Plush', nan, nan, nan]
# ['Captain Marvel Black & White Art Print', nan, nan, nan]
# ['Captain Marvel Art Print', nan, nan, nan]
# ['Avengers: Endgame art print', nan, nan, nan]
# ['Avengers: Endgame Black & White Art Print', nan, nan, nan]
# ['Spider-Man: Far From Home Art Print', nan, nan, nan]
# ['Spider-Man: Far From Home Black & White Art Print', nan, nan, nan]
# ['THE LEGO MOVIE 2: The Second Part (Blu-ray + DVD)', nan, nan, nan]
# ['20th Anniversary Star Wars Poster', nan, nan, nan]
# ['Star Wars 20th anniversary art print', nan, nan, nan]
# ['Minifigure Notebook', 12.66, nan, nan]
# ['Lloyd Luggage Tag', 7.99, nan, nan]
# ['Mechanical Pencil', 3.99, nan, nan]
# ['2x4 Brick Luggage Tag', 7.99, nan, nan]
# ['Red, Bright Blue and Yellow Wall Hanger Set', 14.99, nan, nan]
# ['NASA Apollo 11 Lunar Lander Patch', nan, nan, nan]
# ['Reversible Canvas Tote Bag ', nan, nan, nan]
# ['Minifigure Belight Backpack', 44.99, nan, nan]
# ['Friends Belight Backpack', 44.99, nan, nan]
# ['NINJAGO Belight Backpack', 43.86, nan, nan]
# ['NINJAGO Pencil Roll', 7.99, nan, nan]
# ['Friends Pencil Roll', 7.79, nan, nan]
# ['Minifigure Pencil Roll', 7.79, nan, nan]
# ['Teen Minifigure Backpack', 49.99, nan, nan]
# ['Minifigure Drawstring Bag', 11.69, nan, nan]
# ['Kindergarten Backpack', 19.99, nan, nan]
# ['Minifigure Lunch Box', 6.99, nan, nan]
# ['NINJAGO Lunch Box', 6.81, nan, nan]
# ['Stranger Things Sketchbook', nan, nan, nan]
# ['Stranger Things Poster', nan, nan, nan]
# ['Back to School Pack', nan, nan, nan]
# ['Belgian Patent for LEGO Elements 1958', nan, nan, nan]
# ['1st Edition Elephant Water Colour Print, Circa 1937', nan, nan, nan]
# ['1st Edition of Wooden Duck Print, 1958', nan, nan, nan]
# ['Toy Hen and Chicks Art Print', nan, nan, nan]
# ['Australian Patent LEGO Minifigure 1977', nan, nan, nan]
# ['Japanese Patent LEGO Duplo Brick 1968 Art Print', nan, nan, nan]
# ['VIP Gifting Set', nan, nan, nan]
# ['Picnic Blanket', nan, nan, nan]
# ['LEGO Lunchbox', nan, nan, nan]
# ['LEGO Batman Deluxe Costume', 39.99, nan, nan]
# ['Santa Bag Tag', 7.99, nan, nan]
# ['Holiday Bag Tag R2 D2', nan, nan, nan]
# ['Holiday Bag Tag Chewbacca', 7.79, nan, nan]
# ['Holiday Bag Tag Darth Vader', nan, nan, nan]
# ['Holiday Bag Tag Yoda', 7.79, nan, nan]
# ['Brick Friday 2019 Minifigure', nan, nan, 1.0]
# ['Brick Friday 2019 Brick', nan, 1.0, nan]
# ['LEGO Masters Shopping Bag', nan, nan, nan]
# ['Chewbacca Plush', 26.99, nan, nan]
# ['Lion Dance', nan, nan, nan]
# ['Piglet', nan, 723.0, nan]
# ['Spring', nan, 125.0, nan]
# ['Summer', nan, 103.0, nan]
# ['Autumn', nan, 126.0, nan]
# ['Winter', nan, 113.0, nan]
# ['Reindeer ornament', nan, nan, nan]
# ['Snowman ornament', nan, nan, nan]
# ['Santa ornament', nan, nan, nan]
# ['Christmas tree ornament', nan, nan, nan]
# ['Surfer Van', nan, 62.0, 1.0]
# ['Buildable 2x4 Red Brick', nan, 72.0, nan]
# ['Buildable 2x4 Red Brick', nan, 72.0, nan]
# ['Windmill', nan, 127.0, nan]
# ['Amsterdam BrickHeadz', nan, 110.0, nan]
# ['Tantive IV', nan, 56.0, nan]
# ['Summer Sailboat', nan, 37.0, nan]
# ['100 Stores minifigure', nan, 1.0, 1.0]
# ['Arendelle Castle', nan, 62.0, nan]
# ['Beijing BrickHeadz', nan, 110.0, nan]
# ['Minifigure box', nan, nan, nan]
# ['Löwenstein Castle', nan, 2015.0, 3.0]
# ['Antique Fire Engine', nan, 1278.0, nan]
# ['Skyline Express', nan, 1365.0, 6.0]
# ['Wild West Saloon', nan, 1496.0, nan]
# ['Isle of Peril', nan, 1301.0, nan]
# ['Eight Studs', nan, 1393.0, 2.0]
# ['Science Tower', nan, 1204.0, 2.0]
# ['The LEGO Story', nan, 1442.0, 4.0]
# ['Imagine it! Build it!', nan, 924.0, 2.0]
# ['Hot Shot Carnival ', nan, 591.0, 3.0]
# ['Vintage Roadster', nan, 474.0, nan]
# ['Bikes!', nan, 519.0, 2.0]
# ['Steampunk Mini Chess', nan, 371.0, nan]
# ['Blocks magazine issue 52', nan, nan, nan]
# ['Blocks magazine issue 53', nan, nan, nan]
# ['Blocks magazine issue 54', nan, nan, nan]
# ['Blocks magazine issue 55', nan, nan, nan]
# ['Blocks magazine issue 56', nan, nan, nan]
# ['Blocks magazine issue 57', nan, nan, nan]
# ['Blocks magazine issue 58', nan, nan, nan]
# ['Blocks magazine issue 59', nan, nan, nan]
# ['Blocks magazine issue 60', nan, nan, nan]
# ['Blocks magazine issue 61', nan, nan, nan]
# ['Blocks magazine issue 62', nan, nan, nan]
# ['Blocks magazine issue 63', nan, nan, nan]
# ['Brick Fanatics magazine issue 3', nan, nan, nan]
# ['Brick Fanatics magazine issue 4', nan, nan, nan]
# ['Brick Fanatics magazine issue 5', nan, nan, nan]
# ['Brick Fanatics magazine issue 6', nan, nan, nan]
# ['Brick Fanatics magazine issue 7', nan, nan, nan]
# ['Brick Fanatics magazine issue 8', nan, nan, nan]
# ['Brick Fanatics magazine issue 9', nan, nan, nan]
# ['Brick Fanatics magazine issue 10', nan, nan, nan]
# ['Brick Fanatics magazine issue 11', nan, nan, nan]
# ['Brick Fanatics magazine issue 12', nan, nan, nan]
# ['BrickJournal Issue 55', nan, nan, nan]
# ['BrickJournal Issue 56', nan, nan, nan]
# ['BrickJournal Issue 57', nan, nan, nan]
# ['BrickJournal Issue 58', nan, nan, nan]
# ['BrickJournal Issue 59', nan, nan, nan]
# ['BrickJournal Issue 60', nan, nan, nan]
# ['Mini Captain Marvel Ship', nan, 46.0, nan]
# ['Cologne BrickHeadz', nan, 110.0, nan]
# ['Cool Car', nan, 49.0, nan]
# ['Dragon', nan, 37.0, nan]
# ['Easter Chick', nan, 30.0, nan]
# ['Elephant', nan, nan, nan]
# ["Mini Emmet's Dream House/Rescue Rocket", nan, 68.0, nan]
# ['Flower', nan, nan, nan]
# ['Ganymede', nan, 38.0, nan]
# ['Mini Harley Davidson', nan, 71.0, nan]
# ['LEGO Star Wars: Visual Dictionary, New Edition', nan, 4.0, 1.0]
# ['Star Wars Build Your Own Adventure: Galactic Missions', nan, 66.0, 1.0]
# ['Amazing Vehicles', nan, nan, nan]
# ['Harry Potter Build Your Own Adventure', nan, 101.0, nan]
# ['LEGO NINJAGO: Visual Dictionary, New Edition', nan, 5.0, 1.0]
# ['Christmas Ideas', nan, 41.0, nan]
# ['LEGO Star Wars: Visual Dictionary, Anniversary Edition', nan, 4.0, 1.0]
# ['Harry Potter The Magical Guide to the Wizarding World', nan, nan, nan]
# ['Build Yourself Happy: The Joy of LEGO play', nan, nan, nan]
# ['Lego Action Vehicles: Police Helicopter, Fire Truck, Ambulance, and More', nan, nan, nan]
# ['Expanding the LEGO Winter Village, Volume 2', nan, nan, nan]
# ['Building LEGO BrickHeadz Heroes - Volume One: The Unofficial Guide', nan, nan, nan]
# ['Building LEGO BrickHeadz Villains- Volume One: The Unofficial Guide ', nan, nan, nan]
# ['Expanding the LEGO Winter Village', nan, nan, nan]
# ['Building Tales with Syd and Friends', nan, nan, nan]
# ['New York City Brick by Brick', nan, nan, nan]
# ['The Book of Bedtime Builds', nan, 68.0, nan]
# ['Build It! Wild West', nan, nan, nan]
# ['Build It! Monsters', nan, nan, nan]
# ['Build a LEGO Mustang', nan, nan, nan]
# ['Amazing LEGO Creations from Space with Bricks You Already Have', nan, nan, nan]
# ['The LEGO Castle Book: Build Your Own Mini Medieval World', nan, nan, nan]
# ['Knight Bus', nan, 36.0, nan]
# ['Luke Skywalker', nan, 87.0, nan]
# ['Olaf Box', nan, 50.0, nan]
# ['Panda', nan, nan, nan]
# ['Pig', nan, nan, nan]
# ['Rat', nan, 754.0, nan]
# ['Wally', nan, 47.0, nan]
# ['Barb', nan, 4.0, 1.0]
# ['Zebra Batman', nan, 5.0, nan]
# ['PS4 Spider-Man', nan, 3.0, 1.0]
# ['Golden Snitch', nan, 35.0, nan]
# ['Castle Byers', nan, 48.0, nan]
# ['Stormbreaker', nan, 27.0, nan]
# ['Tantive IV', nan, 56.0, nan]
# ['Tree in the Woods', nan, 53.0, nan]
# ['X-wing Trench Run', nan, 52.0, nan]
# ['Mini X-wing Fighter', nan, 60.0, nan]
